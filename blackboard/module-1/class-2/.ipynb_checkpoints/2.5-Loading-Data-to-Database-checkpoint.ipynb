# %%
from sqlalchemy import create_engine
import json
import sys
from datetime import datetime

# %%
engine = create_engine('postgresql://postgres@localhost:5432/postgres', echo=True)
con = engine.connect()
# Out:
# 2018-10-03 16:51:23,957 INFO sqlalchemy.engine.base.Engine select version()
# 2018-10-03 16:51:23,964 INFO sqlalchemy.engine.base.Engine {}
# 2018-10-03 16:51:23,976 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2018-10-03 16:51:23,980 INFO sqlalchemy.engine.base.Engine {}
# 2018-10-03 16:51:23,988 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2018-10-03 16:51:23,991 INFO sqlalchemy.engine.base.Engine {}
# 2018-10-03 16:51:23,997 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2018-10-03 16:51:24,000 INFO sqlalchemy.engine.base.Engine {}
# 2018-10-03 16:51:24,009 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2018-10-03 16:51:24,013 INFO sqlalchemy.engine.base.Engine {}

# %%
data = json.load(open('data/raw/Lima_2018-10-03_16:29:03.json', 'r'))

# %%
data.keys()
# Out:
# dict_keys(['alerts', 'endTimeMillis', 'irregularities', 'startTimeMillis', 'startTime', 'endTime', 'jams'])

# %%
list(data['jams'][0].keys())
# Out:
# ['country',
#  'city',
#  'level',
#  'line',
#  'speedKMH',
#  'length',
#  'turnType',
#  'type',
#  'uuid',
#  'endNode',
#  'speed',
#  'segments',
#  'roadType',
#  'delay',
#  'street',
#  'pubMillis']

# %%
jams_insert_query = \
                """
                INSERT INTO table_name (
                    uuid,
                    pub_millis,
                    pub_utc_date,
                    start_node,
                    end_node,
                    road_type,
                    street,
                    city,
                    country,
                    delay,
                    speed,
                    speed_kmh,
                    length,
                    turn_type,
                    level,
                    blocking_alert_id,
                    line,
                    type,
                    turn_line)
                VALUES (
                    {uuid},
                    {pub_millis},
                    '{pub_utc_date}',
                    {start_node},
                    {end_node},
                    {road_type},
                    {street},
                    {city},
                    {country},
                    {delay},
                    {speed},
                    {speed_kmh},
                    {length},
                    {turn_type},
                    {level},
                    {blocking_alert_id},
                    {line},
                    {type},
                    {turn_line});
                """

# %%
from collections import defaultdict

# %%
a= defaultdict(lambda: None)

# %%
b = a['joao']

# %%
def to_default_dict(list_of_dic):
    return [defaultdict(lambda: None, dic) for dic in list_of_dic]

jams, alerts, irregularities = list(map(to_default_dict, 
                                        [data['jams'], data['alerts'], data['irregularities']]))

# %%
jam = jams[0]
ex = con.execute(jams_insert_query.format(
                    uuid=jam['uuid'],
                    pub_millis=jam['pubMillis'],
                    pub_utc_date=data['startTime'],
                    start_node=jam['startNode'],
                    end_node=jam['endNode'],
                    road_type=jam['roadType'],
                    street=jam['street'],
                    city=jam['city'],
                    country=jam['country'],
                    delay=jam['delay'],
                    speed=jam['speed'],
                    speed_kmh=jam['speedKMH'],
                    length=jam['length'],
                    turn_type=jam['turnType'],
                    level=jam['level'],
                    blocking_alert_id=jam['blockingAlertId'],
                    line=jam['line'],
                    type=jam['type'],
                    turn_line=jam['turnType']
                ))
# Out:
# 2018-10-03 17:28:15,555 INFO sqlalchemy.engine.base.Engine
#                 INSERT INTO table_name (
#                     uuid,
#                     pub_millis,
#                     pub_utc_date,
#                     start_node,
#                     end_node,
#                     road_type,
#                     street,
#                     city,
#                     country,
#                     delay,
#                     speed,
#                     speed_kmh,
#                     length,
#                     turn_type,
#                     level,
#                     blocking_alert_id,
#                     line,
#                     type,
#                     ns_direction,
#                     ew_direction,
#                     dayofweek,
#                     turn_line)
#                 VALUES (
#                     1265563837,
#                     1538587878938,
#                     2018-10-03 19:26:00,
#                     None,
# ...

# %%
# Out:
# {'alerts': [{'city': 'Santiago de Surco',
#    'confidence': 0,
#    'country': 'PE',
#    'location': {'x': -76.994011, 'y': -12.138943},
#    'magvar': 145,
#    'nThumbsUp': 0,
#    'pubMillis': 1538594635722,
#    'reliability': 6,
#    'reportRating': 1,
#    'roadType': 2,
#    'street': 'Av. Santiago de Surco - Solo Transporte Público',
#    'subtype': 'JAM_STAND_STILL_TRAFFIC',
#    'type': 'JAM',
#    'uuid': '4f2fb262-2dae-37ac-a0ad-b52c688f3d66'},
#   {'city': 'Santiago de Surco',
#    'confidence': 0,
#    'country': 'PE',
#    'location': {'x': -76.994096, 'y': -12.139003},
#    'magvar': 144,
#    'nThumbsUp': 0,
#    'pubMillis': 1538594669356,
#    'reliability': 5,
#    'reportRating': 1,
#    'roadType': 1,
#    'street': 'Auxiliar Av. Santiago de Surco',
#    'subtype': 'JAM_HEAVY_TRAFFIC',
#    'type': 'JAM',
#    'uuid': 'ca9406f8-bac5-3766-baed-3a73ccfc1223'},
#   {'city': 'Santiago de Surco',
#    'confidence': 0,
#    'country': 'PE',
# ...
