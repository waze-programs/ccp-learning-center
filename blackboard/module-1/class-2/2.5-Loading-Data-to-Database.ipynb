# %%
from sqlalchemy import create_engine, MetaData
import json
import sys
from datetime import datetime
from collections import defaultdict

# %%
engine = create_engine('postgresql://postgres@localhost:5432/postgres', echo=True)
con = engine.connect()
# Out:
# 2018-10-03 21:18:56,618 INFO sqlalchemy.engine.base.Engine select version()
# 2018-10-03 21:18:56,620 INFO sqlalchemy.engine.base.Engine {}
# 2018-10-03 21:18:56,624 INFO sqlalchemy.engine.base.Engine select current_schema()
# 2018-10-03 21:18:56,627 INFO sqlalchemy.engine.base.Engine {}
# 2018-10-03 21:18:56,636 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2018-10-03 21:18:56,638 INFO sqlalchemy.engine.base.Engine {}
# 2018-10-03 21:18:56,643 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2018-10-03 21:18:56,645 INFO sqlalchemy.engine.base.Engine {}
# 2018-10-03 21:18:56,649 INFO sqlalchemy.engine.base.Engine show standard_conforming_strings
# 2018-10-03 21:18:56,651 INFO sqlalchemy.engine.base.Engine {}

# %% [markdown]
# ## Load waze data from json

# %%
data = json.load(open('data/raw/Lima_2018-10-03_16:29:03.json', 'r'))

# %%
data.keys()
# Out:
# dict_keys(['alerts', 'endTimeMillis', 'irregularities', 'startTimeMillis', 'startTime', 'endTime', 'jams'])

# %%
def to_default_dict(list_of_dic):
    return [defaultdict(lambda: None, dic) for dic in list_of_dic]

jams, alerts, irregularities = list(map(to_default_dict, 
                                        [data['jams'], data['alerts'], data['irregularities']]))

# %% [markdown]
# ## Load Schema from DB

# %%
metadata = MetaData()
metadata.reflect(engine, schema='waze')

# %%
metadata.tables['waze.jams']
# Out:
# Table('jams', MetaData(bind=None), Column('id', INTEGER(), table=<jams>, primary_key=True, nullable=False, server_default=DefaultClause(<sqlalchemy.sql.elements.TextClause object at 0x11388ae80>, for_update=False)), Column('uuid', TEXT(), table=<jams>, nullable=False), Column('pub_millis', BIGINT(), table=<jams>, nullable=False), Column('pub_utc_date', TIMESTAMP(), table=<jams>), Column('start_node', TEXT(), table=<jams>), Column('end_node', TEXT(), table=<jams>), Column('road_type', SMALLINT(), table=<jams>), Column('street', TEXT(), table=<jams>), Column('city', TEXT(), table=<jams>), Column('country', TEXT(), table=<jams>), Column('delay', SMALLINT(), table=<jams>), Column('speed', REAL(), table=<jams>), Column('speed_kmh', REAL(), table=<jams>), Column('length', SMALLINT(), table=<jams>), Column('turn_type', TEXT(), table=<jams>), Column('level', SMALLINT(), table=<jams>), Column('blocking_alert_id', TEXT(), table=<jams>), Column('line', JSON(astext_type=Text()), table=<jams>), Column('type', TEXT(), table=<jams>), Column('ns_direction', TEXT(), table=<jams>), Column('ew_direction', TEXT(), table=<jams>), Column('dayofweek', INTEGER(), table=<jams>), Column('turn_line', TEXT(), table=<jams>), schema='waze')

# %% [markdown]
# ## Insert jams to DB

# %%
def make_jam_dict(jam, data):
    return dict(uuid=jam['uuid'],
                pub_millis=jam['pubMillis'],
                pub_utc_date=datetime.strptime(data['startTime'], '%Y-%m-%d %H:%M:%S:%f'),
                start_node=jam['startNode'],
                end_node=jam['endNode'],
                road_type=jam['roadType'],
                street=jam['street'],
                city=jam['city'],
                country=jam['country'],
                delay=jam['delay'],
                speed=jam['speed'],
                speed_kmh=jam['speedKMH'],
                length=jam['length'],
                turn_type=jam['turnType'],
                level=jam['level'],
                blocking_alert_id=jam['blockingAlertId'],
                line=jam['line'],
                type=jam['type'],
                turn_line=jam['turnType'])

# %%
with engine.connect() as conn:
    for jam in jams:
        conn.execute(metadata.tables['waze.jams'].insert(), make_jam_dict(jam, data))
# Out:
# 2018-10-03 21:16:21,159 INFO sqlalchemy.engine.base.Engine INSERT INTO waze.jams (uuid, pub_millis, pub_utc_date, start_node, end_node, road_type, street, city, country, delay, speed, speed_kmh, length, turn_type, level, blocking_alert_id, line, type, turn_line) VALUES (%(uuid)s, %(pub_millis)s, %(pub_utc_date)s, %(start_node)s, %(end_node)s, %(road_type)s, %(street)s, %(city)s, %(country)s, %(delay)s, %(speed)s, %(speed_kmh)s, %(length)s, %(turn_type)s, %(level)s, %(blocking_alert_id)s, %(line)s, %(type)s, %(turn_line)s) RETURNING waze.jams.id
# 2018-10-03 21:16:21,163 INFO sqlalchemy.engine.base.Engine {'uuid': 1265563837, 'pub_millis': 1538587878938, 'pub_utc_date': datetime.datetime(2018, 10, 3, 19, 26), 'start_node': None, 'end_node': 'Av. Ariosto Matellini', 'road_type': 2, 'street': 'Av. Defensores del Morro', 'city': 'Chorrillos', 'country': 'PE', 'delay': 138, 'speed': 4.097222222222222, 'speed_kmh': 14.75, 'length': 784, 'turn_type': 'NONE', 'level': 3, 'blocking_alert_id': None, 'line': '[{"x": -77.017502, "y": -12.176187}, {"x": -77.015862, "y": -12.177788}, {"x": -77.014859, "y": -12.178844}, {"x": -77.014804, "y": -12.1789}, {"x": -77.014072, "y": -12.179659}, {"x": -77.013204, "y": -12.180554}, {"x": -77.012619, "y": -12.181184}, {"x": -77.012511, "y": -12.181297}]', 'type': 'NONE', 'turn_line': 'NONE'}
# 2018-10-03 21:16:21,177 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-10-03 21:16:21,183 INFO sqlalchemy.engine.base.Engine INSERT INTO waze.jams (uuid, pub_millis, pub_utc_date, start_node, end_node, road_type, street, city, country, delay, speed, speed_kmh, length, turn_type, level, blocking_alert_id, line, type, turn_line) VALUES (%(uuid)s, %(pub_millis)s, %(pub_utc_date)s, %(start_node)s, %(end_node)s, %(road_type)s, %(street)s, %(city)s, %(country)s, %(delay)s, %(speed)s, %(speed_kmh)s, %(length)s, %(turn_type)s, %(level)s, %(blocking_alert_id)s, %(line)s, %(type)s, %(turn_line)s) RETURNING waze.jams.id
# 2018-10-03 21:16:21,186 INFO sqlalchemy.engine.base.Engine {'uuid': 1284002045, 'pub_millis': 1538594006566, 'pub_utc_date': datetime.datetime(2018, 10, 3, 19, 26), 'start_node': None, 'end_node': 'Av. Paseo de la República', 'road_type': 1, 'street': 'Prolongación Paseo de la República', 'city': 'Chorrillos', 'country': 'PE', 'delay': 171, 'speed': 2.6944444444444446, 'speed_kmh': 9.700000000000001, 'length': 654, 'turn_type': 'NONE', 'level': 3, 'blocking_alert_id': None, 'line': '[{"x": -77.01508, "y": -12.17352}, {"x": -77.01288, "y": -12.175953}, {"x": -77.012219, "y": -12.176706}, {"x": -77.011886, "y": -12.177071}, {"x": -77.011527, "y": -12.177465}, {"x": -77.011096, "y": -12.177946}]', 'type': 'NONE', 'turn_line': 'NONE'}
# 2018-10-03 21:16:21,198 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-10-03 21:16:21,202 INFO sqlalchemy.engine.base.Engine INSERT INTO waze.jams (uuid, pub_millis, pub_utc_date, start_node, end_node, road_type, street, city, country, delay, speed, speed_kmh, length, turn_type, level, blocking_alert_id, line, type, turn_line) VALUES (%(uuid)s, %(pub_millis)s, %(pub_utc_date)s, %(start_node)s, %(end_node)s, %(road_type)s, %(street)s, %(city)s, %(country)s, %(delay)s, %(speed)s, %(speed_kmh)s, %(length)s, %(turn_type)s, %(level)s, %(blocking_alert_id)s, %(line)s, %(type)s, %(turn_line)s) RETURNING waze.jams.id
# 2018-10-03 21:16:21,204 INFO sqlalchemy.engine.base.Engine {'uuid': 1284516845, 'pub_millis': 1538594695630, 'pub_utc_date': datetime.datetime(2018, 10, 3, 19, 26), 'start_node': None, 'end_node': 'U', 'road_type': 2, 'street': 'Av. Defensores del Morro', 'city': 'Chorrillos', 'country': 'PE', 'delay': 75, 'speed': 4.238888888888889, 'speed_kmh': 15.26, 'length': 686, 'turn_type': 'NONE', 'level': 2, 'blocking_alert_id': None, 'line': '[{"x": -77.007657, "y": -12.184743}, {"x": -77.007614, "y": -12.184916}, {"x": -77.007612, "y": -12.185046}, {"x": -77.007659, "y": -12.185803}, {"x" ... (273 characters truncated) ... 18951}, {"x": -77.006907, "y": -12.189792}, {"x": -77.00638, "y": -12.19024}, {"x": -77.006312, "y": -12.190297}, {"x": -77.006247, "y": -12.190356}]', 'type': 'NONE', 'turn_line': 'NONE'}
# 2018-10-03 21:16:21,210 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-10-03 21:16:21,214 INFO sqlalchemy.engine.base.Engine INSERT INTO waze.jams (uuid, pub_millis, pub_utc_date, start_node, end_node, road_type, street, city, country, delay, speed, speed_kmh, length, turn_type, level, blocking_alert_id, line, type, turn_line) VALUES (%(uuid)s, %(pub_millis)s, %(pub_utc_date)s, %(start_node)s, %(end_node)s, %(road_type)s, %(street)s, %(city)s, %(country)s, %(delay)s, %(speed)s, %(speed_kmh)s, %(length)s, %(turn_type)s, %(level)s, %(blocking_alert_id)s, %(line)s, %(type)s, %(turn_line)s) RETURNING waze.jams.id
# 2018-10-03 21:16:21,217 INFO sqlalchemy.engine.base.Engine {'uuid': 1287172064, 'pub_millis': 1538593998065, 'pub_utc_date': datetime.datetime(2018, 10, 3, 19, 26), 'start_node': None, 'end_node': 'Av. Malecón Grau', 'road_type': 2, 'street': 'Av. Defensores del Morro', 'city': 'Chorrillos', 'country': 'PE', 'delay': 260, 'speed': 4.3277777777777775, 'speed_kmh': 15.58, 'length': 1767, 'turn_type': 'NONE', 'level': 3, 'blocking_alert_id': None, 'line': '[{"x": -77.014626, "y": -12.178868}, {"x": -77.015843, "y": -12.17761}, {"x": -77.017675, "y": -12.175797}, {"x": -77.018347, "y": -12.175102}, {"x": ... (309 characters truncated) ... 0017}, {"x": -77.023555, "y": -12.169626}, {"x": -77.02456, "y": -12.168585}, {"x": -77.025315, "y": -12.167832}, {"x": -77.025835, "y": -12.167319}]', 'type': 'NONE', 'turn_line': 'NONE'}
# 2018-10-03 21:16:21
]', 'type': 'NONE', 'turn_line': 'NONE'}
# 2018-10-03 21:16:21,589 INFO sqlalchemy.engine.base.Engine COMMIT
# ...
# 2018-10-03 21:16:26,624 INFO sqlalchemy.engine.base.Engine {'uuid': 1274436546, 'pub_millis': 1538594695457, 'pub_utc_date': datetime.datetime(2018, 10, 3, 19, 26), 'start_node': None, 'end_node': 'Av. Ampliacion Oeste', 'road_type': 2, 'street': 'Av. Ampliación Oeste', 'city': 'San Juan de Lurigancho', 'country': 'PE', 'delay': 91, 'speed': 4.186111111111111, 'speed_kmh': 15.07, 'length': 843, 'turn_type': 'NONE', 'level': 2, 'blocking_alert_id': None, 'line': '[{"x": -76.9819, "y": -11.943532}, {"x": -76.982219, "y": -11.943319}, {"x": -76.982698, "y": -11.942998}, {"x": -76.984934, "y": -11.9415}, {"x": -76.98571, "y": -11.94098}, {"x": -76.986034, "y": -11.940763}, {"x": -76.987199, "y": -11.939982}, {"x": -76.988298, "y": -11.939246}]', 'type': 'NONE', 'turn_line': 'NONE'}
# 2018-10-03 21:16:26,628 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-10-03 21:16:26,632 INFO sqlalchemy.engine.base.Engine INSERT INTO waze.jams (uuid, pub_millis, pub_utc_date, start_node, end_node, road_type, street, city, country, delay, speed, speed_kmh, length, turn_type, level, blocking_alert_id, line, type, turn_line) VALUES (%(uuid)s, %(pub_millis)s, %(pub_utc_date)s, %(start_node)s, %(end_node)s, %(road_type)s, %(street)s, %(city)s, %(country)s, %(delay)s, %(speed)s, %(speed_kmh)s, %(length)s, %(turn_type)s, %(level)s, %(blocking_alert_id)s, %(line)s, %(type)s, %(turn_line)s) RETURNING waze.jams.id
# 2018-10-03 21:16:26,634 INFO sqlalchemy.engine.base.Engine {'uuid': 1270058959, 'pub_millis': 1538594793273, 'pub_utc_date': datetime.datetime(2018, 10, 3, 19, 26), 'start_node': None, 'end_node': None, 'road_type': 3, 'street': 'PE-20/Av. Néstor Gambetta', 'city': 'Ventanilla', 'country': 'PE', 'delay': 148, 'speed': 1.5138888888888888, 'speed_kmh': 5.45, 'length': 273, 'turn_type': 'NONE', 'level': 4, 'blocking_alert_id': None, 'line': '[{"x": -77.11094, "y": -11.837394}, {"x": -77.112051, "y": -11.838533}, {"x": -77.112676, "y": -11.839172}]', 'type': 'NONE', 'turn_line': 'NONE'}
# 2018-10-03 21:16:26,637 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-10-03 21:16:26,642 INFO sqlalchemy.engine.base.Engine INSERT INTO waze.jams (uuid, pub_millis, pub_utc_date, start_node, end_node, road_type, street, city, country, delay, speed, speed_kmh, length, turn_type, level, blocking_alert_id, line, type, turn_line) VALUES (%(uuid)s, %(pub_millis)s, %(pub_utc_date)s, %(start_node)s, %(end_node)s, %(road_type)s, %(street)s, %(city)s, %(country)s, %(delay)s, %(speed)s, %(speed_kmh)s, %(length)s, %(turn_type)s, %(level)s, %(blocking_alert_id)s, %(line)s, %(type)s, %(turn_line)s) RETURNING waze.jams.id
# 2018-10-03 21:16:26,644 INFO sqlalchemy.engine.base.Engine {'uuid': 1272707567, 'pub_millis': 1538594801981, 'pub_utc_date': datetime.datetime(2018, 10, 3, 19, 26), 'start_node': None, 'end_node': 'Calle 11', 'road_type': 3, 'street': 'PE-20/Av. Néstor Gambetta', 'city': 'Ventanilla', 'country': 'PE', 'delay': 68, 'speed': 6.933333333333334, 'speed_kmh': 24.96, 'length': 1244, 'turn_type': 'NONE', 'level': 1, 'blocking_alert_id': None, 'line': '[{"x": -77.129593, "y": -11.8526}, {"x": -77.129742, "y": -11.852895}, {"x": -77.129834, "y": -11.85315}, {"x": -77.129944, "y": -11.853638}, {"x": - ... (412 characters truncated) ... 61911}, {"x": -77.129037, "y": -11.862237}, {"x": -77.128978, "y": -11.86266}, {"x": -77.128951, "y": -11.863028}, {"x": -77.12891, "y": -11.863355}]', 'type': 'NONE', 'turn_line': 'NONE'}
# 2018-10-03 21:16:26,647 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-10-03 21:16:26,651 INFO sqlalchemy.engine.base.Engine INSERT INTO waze.jams (uuid, pub_millis, pub_utc_date, start_node, end_node, road_type, street, city, country, delay, speed, speed_kmh, length, turn_type, level, blocking_alert_id, line, type, turn_line) VALUES (%(uuid)s, %(pub_millis)s, %(pub_utc_date)s, %(start_node)s, %(end_node)s, %(road_type)s, %(street)s, %(city)s, %(country)s, %(delay)s, %(speed)s, %(speed_kmh)s, %(length)s, %(turn_type)s, %(level)s, %(blocking_alert_id)s, %(line)s, %(type)s, %(turn_line)s) RETURNING waze.jams.id
# 2018-10-03 21:16:26,653 INFO sqlalchemy.engine.base.Engine {'uuid': 1273564718, 'pub_millis': 1538594894115, 'pub_utc_date': datetime.datetime(2018, 10, 3, 19, 26), 'start_node': None, 'end_node': 'Av. Industrial', 'road_type': 2, 'street': 'Av. Los Próceres de Huandoy', 'city': 'Los Olivos', 'country': 'PE', 'delay': 77, 'speed': 1.2694444444444444, 'speed_kmh': 4.57, 'length': 164, 'turn_type': 'NONE', 'level': 4, 'blocking_alert_id': None, 'line': '[{"x": -77.072758, "y": -11.937797}, {"x": -77.072207, "y": -11.937755}, {"x": -77.071793, "y": -11.937724}, {"x": -77.071668, "y": -11.937703}, {"x": -77.071256, "y": -11.937653}]', 'type': 'NONE', 'turn_line': 'NONE'}
# 2018-10-03 21:16:26,656 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-10-03 21:16:26,663 INFO sqlalchemy.engine.base.Engine INSERT INTO waze.jams (uuid, pub_millis, pub_utc_date, start_node, end_node, road_type, street, city, country, delay, speed, speed_kmh, length, turn_type, level, blocking_alert_id, line, type, turn_line) VALUES (%(uuid)s, %(pub_millis)s, %(pub_utc_date)s, %(start_node)s, %(end_node)s, %(road_type)s, %(street)s, %(city)s, %(country)s, %(delay)s, %(speed)s, %(speed_kmh)s, %(length)s, %(turn_type)s, %(level)s, %(blocking_alert_id)s, %(line)s, %(type)s, %(turn_line)s) RETURNING waze.jams.id
# 2018-10-03 21:16:26,665 INFO sqlalchemy.engine.base.Engine {'uuid': 1309586093, 'pub_millis': 1538594894904, 'pub_utc_date': datetime.datetime(2018, 10, 3, 19, 26), 'start_node': None, 'end_node': 'Saenz Peña', 'road_type': 1, 'street': 'Moquegua', 'city': 'Carabayllo', 'country': 'PE', 'delay': 132, 'speed': 1.2944444444444445, 'speed_kmh': 4.66, 'length': 195, 'turn_type': 'NONE', 'level': 4, 'blocking_alert_id': None, 'line': '[{"x": -77
]', 'type': 'NONE', 'turn_line': 'NONE'}
# 2018-10-03 21:16:26,707 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-10-03 21:16:26,711 INFO sqlalchemy.engine.base.Engine INSERT INTO waze.jams (uuid, pub_millis, pub_utc_date, start_node, end_node, road_type, street, city, country, delay, speed, speed_kmh, length, turn_type, level, blocking_alert_id, line, type, turn_line) VALUES (%(uuid)s, %(pub_millis)s, %(pub_utc_date)s, %(start_node)s, %(end_node)s, %(road_type)s, %(street)s, %(city)s, %(country)s, %(delay)s, %(speed)s, %(speed_kmh)s, %(length)s, %(turn_type)s, %(level)s, %(blocking_alert_id)s, %(line)s, %(type)s, %(turn_line)s) RETURNING waze.jams.id
# 2018-10-03 21:16:26,712 INFO sqlalchemy.engine.base.Engine {'uuid': 1267304110, 'pub_millis': 1538594485828, 'pub_utc_date': datetime.datetime(2018, 10, 3, 19, 26), 'start_node': None, 'end_node': 'U', 'road_type': 2, 'street': 'Av. San Lorenzo', 'city': 'Puente Piedra', 'country': 'PE', 'delay': 73, 'speed': 3.808333333333333, 'speed_kmh': 13.709999999999999, 'length': 611, 'turn_type': 'NONE', 'level': 2, 'blocking_alert_id': None, 'line': '[{"x": -77.066325, "y": -11.855224}, {"x": -77.067006, "y": -11.856047}, {"x": -77.067057, "y": -11.856117}, {"x": -77.067285, "y": -11.856425}, {"x" ... (96 characters truncated) ... 228}, {"x": -77.069188, "y": -11.858682}, {"x": -77.069543, "y": -11.859113}, {"x": -77.069678, "y": -11.859274}, {"x": -77.069876, "y": -11.859513}]', 'type': 'NONE', 'turn_line': 'NONE'}
# 2018-10-03 21:16:26,715 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-10-03 21:16:26,719 INFO sqlalchemy.engine.base.Engine INSERT INTO waze.jams (uuid, pub_millis, pub_utc_date, start_node, end_node, road_type, street, city, country, delay, speed, speed_kmh, length, turn_type, level, blocking_alert_id, line, type, turn_line) VALUES (%(uuid)s, %(pub_millis)s, %(pub_utc_date)s, %(start_node)s, %(end_node)s, %(road_type)s, %(street)s, %(city)s, %(country)s, %(delay)s, %(speed)s, %(speed_kmh)s, %(length)s, %(turn_type)s, %(level)s, %(blocking_alert_id)s, %(line)s, %(type)s, %(turn_line)s) RETURNING waze.jams.id
# 2018-10-03 21:16:26,720 INFO sqlalchemy.engine.base.Engine {'uuid': 1269907249, 'pub_millis': 1538594590523, 'pub_utc_date': datetime.datetime(2018, 10, 3, 19, 26), 'start_node': None, 'end_node': 'Av. Universitaria', 'road_type': 2, 'street': 'Av. Los Incas', 'city': 'Comas', 'country': 'PE', 'delay': 119, 'speed': 1.5444444444444445, 'speed_kmh': 5.5600000000000005, 'length': 232, 'turn_type': 'NONE', 'level': 3, 'blocking_alert_id': None, 'line': '[{"x": -77.050051, "y": -11.914045}, {"x": -77.04994, "y": -11.914105}, {"x": -77.048782, "y": -11.914759}, {"x": -77.048191, "y": -11.91507}]', 'type': 'NONE', 'turn_line': 'NONE'}
# 2018-10-03 21:16:26,724 INFO sqlalchemy.engine.base.Engine COMMIT
# 2018-10-03 21:16:26,728 INFO sqlalchemy.engine.base.Engine INSERT INTO waze.jams (uuid, pub_millis, pub_utc_date, start_node, end_node, road_type, street, city, country, delay, speed, speed_kmh, length, turn_type, level, blocking_alert_id, line, type, turn_line) VALUES (%(uuid)s, %(pub_millis)s, %(pub_utc_date)s, %(start_node)s, %(end_node)s, %(road_type)s, %(street)s, %(city)s, %(country)s, %(delay)s, %(speed)s, %(speed_kmh)s, %(length)s, %(turn_type)s, %(level)s, %(blocking_alert_id)s, %(line)s, %(type)s, %(turn_line)s) RETURNING waze.jams.id
# 2018-10-03 21:16:26,729 INFO sqlalchemy.engine.base.Engine {'uuid': 1309348493, 'pub_millis': 1538594590925, 'pub_utc_date': datetime.datetime(2018, 10, 3, 19, 26), 'start_node': None, 'end_node': None, 'road_type': 2, 'street': 'Av. Micaela Bastidas', 'city': 'Comas', 'country': 'PE', 'delay': 63, 'speed': 1.8666666666666667, 'speed_kmh': 6.720000000000001, 'length': 226, 'turn_type': 'NONE', 'level': 3, 'blocking_alert_id': None, 'line': '[{"x": -77.052634, "y": -11.930467}, {"x": -77.053265, "y": -11.930136}, {"x": -77.05348, "y": -11.930003}, {"x": -77.053681, "y": -11.929889}, {"x": -77.053791, "y": -11.929842}, {"x": -77.054368, "y": -11.929535}, {"x": -77.054458, "y": -11.929491}]', 'type': 'NONE', 'turn_line': 'NONE'}
# 2018-10-03 21:16:26,735 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
from pathlib import Path

# %%
p = Path('.').parent / 'data' / 'raw'

# %%
a = list(p.glob('*.json'))[0]

# %%
import os

# %%
os.rename(a, p.parent / 'processed' / a.name)
